# %%
import pymysql
from cryptography.fernet import Fernet
import json
from collections import namedtuple
import time
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline

# %% [markdown]
# <b> Decrypt the credentials </b>

# %%
#Uncode the secret license file
def unencrypt():
    try:
        key = b'IXx5rHfP15FqP4ahx2pwcud-XmcBzU553Ri6p-nVhnc=' #Fernet.generate_key()
        cipher_suite = Fernet(key)
        with open('/usr/local/etc/musicmood_bytes.bin', 'rb') as file_object:
            for line in file_object:
                encryptedpwd = line
        uncipher_text = (cipher_suite.decrypt(encryptedpwd))
        plain_text_encryptedpassword = bytes(uncipher_text).decode("utf-8") #convert to string
        x = json.loads(plain_text_encryptedpassword, object_hook=lambda d: namedtuple('X', d.keys())(*d.values()))
        return x
    except Exception as e:
        print(str(e))
        return "Error"

# %% [markdown]
# <b> Connect to the Database </b>

# %%
#Setup the database connection
credentials = unencrypt()
user_id = credentials.user
user_password = credentials.password
dbname = credentials.dbname
server = credentials.server
conn = pymysql.connect(server,user_id,user_password,dbname)

# %% [markdown]
# <b> Obtain the data from the Database </b>

# %%
start_time = time.time()
df = pd.read_sql('SELECT * FROM song_artist_universe where trackid IS NOT NULL', con = conn)
print("--- %s seconds ---" % (time.time() - start_time))
df.head(15)
# Out:
# --- 0.18390989303588867 seconds ---
#     id                      song                artist         artist_kaggle  \
# 0    5                      When           Kalin Twins           kalin-twins
# 1    7                Yakety Yak          The Coasters          the-coasters
# 2    9  Willie And The Hand Jive  The Johnny Otis Show  the-johnny-otis-show
# 3   11              Ginger Bread        Frankie Avalon        frankie-avalon
# 4   16          One Summer Night          The Danleers          the-danleers
# 5   17             Endless Sleep         Jody Reynolds         jody-reynolds
# 6   18               Little Star          The Elegants          the-elegants
# 7   20      Do You Want To Dance         Bobby Freeman         bobby-freeman
# 8   22           A Certain Smile         Johnny Mathis         johnny-mathis
# 9   24   The Purple People Eater           Sheb Wooley           sheb-wooley
# 10  25      What Am I Living For          Chuck Willis          chuck-willis
# 11  28                  Secretly        Jimmie Rodgers        jimmie-rodgers
# 12  31            Chantilly Lace            Big Bopper            big-bopper
# 13  32             Blue Blue Day            Don Gibson            don-gibson
# 14  47              I Wonder Why   Dion & The Belmonts   dion-&-the-belmonts
#
#                  song_kaggle  year_kaggle  id_lyrics_kaggle  \
# 0                       when         1957               NaN
# 1                 yakety-yak         1957          251785.0
# 2   willie-and-the-hand-jive         1957               NaN
# 3               ginger-bread         1957               NaN
# 4           one-summer-night         1957               NaN
# 5              endless-sleep         1957               NaN
# 6                little-star         1957               NaN
# 7       do-you-want-to-dance         1957               NaN
# 8            a-certain-smile         1957               NaN
# 9    the-purple-people-eater         1957               NaN
# 10      what-am-i-living-for         1957               NaN
# 11                  secretly         1957               NaN
# 12            chantilly-lace         1957           86048.0
# 13             blue-blue-day         1957          321890.0
# 14              i-wonder-why         1957               NaN
#
#                trackid  num_weeks  bill_popularity
# 0   TRRMVWJ128F9349163         91           8444.0
# 1   TRASRKW128F92FAFE4         89           8054.0
# 2   TRHFTUX128F93010D0         92           8199.0
# 3   TRFZQYY128F9333424         93           8057.0
# 4   TRIWIBF128F93309F6         90           7439.0
# 5   TRMWBBX128F930100E         88           7077.0
# 6   TRCBTTH12903CCBDE9         99           8113.0
# 7   TRGBMDY128F932D49D         87           6848.0
# 8   TRZOGKV128F92FE7E9         91           6910.0
# 9   TRGNVEQ128F92F9954         86           6387.0
# 10  TRQHRIG12903CE6ABE         89           6484.0
# 11  TRXXOQS128F930101A         85           6058.0
# 12  TRWFFRG128F92FE8F3        104           7374.0
# 13  TRAPESV128F92FE5E9         90           5978.0
# 14  TRMSWHL128F92FA114         84           4439.0

# %% [markdown]
# <B> Describe the dataset </B>

# %%
df.describe()
# Out:
#                  id  year_kaggle  id_lyrics_kaggle    num_weeks  \
# count   6983.000000  6983.000000       1811.000000  6983.000000
# mean   12874.956609  1982.678935     187921.344561    13.588143
# std     6775.989580    15.034069      99836.148230     8.812242
# min        5.000000  1957.000000        100.000000     1.000000
# 25%     7237.500000  1969.000000     106762.000000     8.000000
# 50%    13311.000000  1981.000000     194353.000000    13.000000
# 75%    18780.500000  1995.000000     269668.000000    19.000000
# max    26449.000000  2017.000000     361822.000000   104.000000
#
#        bill_popularity
# count      6983.000000
# mean        734.238293
# std         686.892263
# min           0.000000
# 25%         211.000000
# 50%         615.000000
# 75%        1085.000000
# max        8444.000000

# %% [markdown]
# <b> Histograms </b>

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a193eb7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a19494cf8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a194cddd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a19503eb8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a19524048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a19548080>]],
#       dtype=object)

# %%
import seaborn as sns; sns.set(style="ticks", color_codes=True)
import matplotlib.pyplot as plt

# %%
g = sns.pairplot(df, size=4, vars=['year_kaggle','num_weeks','bill_popularity'], kind="reg")
